# %% [markdown]
# <a href="https://colab.research.google.com/github/zzh2027/zzh2027.github.io/blob/master/%E7%BB%99%E4%BD%A0%E7%94%BB%E4%B8%AA%E2%9D%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##  -->> print a heart <<--
num = int(input("Enter your number here~"))
for i in range(num):
    for j in range(2*(num - i -1)):
        print("\033[1;31;46m ",end = "")
    for j in range(i + 1):
        print("\033[1;31;41m    ",end = "")
    for j in range(4*(num-i-1)):#0,1,2,3  --> 6,4,2,0
        print("\033[1;31;46m ",end= "")
    for j in range(i+1):
        print("\033[1;31;41m    ",end = "")
    for j in range(2*(num - i -1)):
        print("\033[1;31;46m ",end = "")
    print()
for i in range(num//2):
    for j in range(2*num):
        print("\033[1;31;41m    ",end = "")
    print()
for i in range(2*num):
    for j in range(i):
        print("\033[1;31;46m  ",end = "")
    for j in range(2*num-i):
        print("\033[1;31;41m    ",end = "")
    for j in range(i):
        print("\033[1;31;46m  ",end = "")
    
    print()
# Out:
# Enter your number here~9
