# %%
from PictureReconstruction import Fuzzy


test = mpimg.imread("trump.jpg")
s = Fuzzy(test)    
s.show_img(0.07)
# Out:
# 2020-05-28 18:19:12.490 | INFO     | SVD:show_img:84 - Drawing pictures...
